# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### PCA - Used to reduce dimensions - Unsupervised learning
#
# 1) Standardize the dataset.
# 2) Compute Covaraince Matrix from the Standardized dataset.
# 3) Compute Eigen values and eigen vectors from the Covaraince Matrix.
# Arrange Eigen Vectors in decreasing order of Eigen values.
#
# 4) Select Feature matrix which is min number of eigen vectors required to generate the principal components.
# 5) Generate Pcincipal Components from the Feature matrix

# %% [markdown]
# ### APPLICATIONS OF PCA :
#
# 1) Dimension Reductions.<br>
# 2) Preventing Overfitting.<br>
# 3) Removes MultiCollinearity {Uncorrelated features}.<br>
# 4) Model Execution Time Reduces.<br>
# 5) Feature Extraction.

# %% [markdown]
# ### Read the Dataset :

# %%
df = pd.read_csv('houseprice.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Data PreProcessing :

# %% [markdown]
# #### 1) Handle Null Values :

# %%
def fetch_null_val(data):
    nv = data.isnull().sum()
    nv = nv[nv>0]
    nv_df = pd.DataFrame({'Feature':nv.index,'Null_Count':nv.values,
                         '%Null':(nv.values/data.shape[0])*100})
    nv_df = nv_df.sort_values('%Null',ascending=False)
    return nv_df

# %%
nv_df = fetch_null_val(df)
nv_df
# Out:
#          Feature  Null_Count      %Null
# 16        PoolQC        1453  99.520548
# 18   MiscFeature        1406  96.301370
# 1          Alley        1369  93.767123
# 17         Fence        1179  80.753425
# 2     MasVnrType         872  59.726027
# 10   FireplaceQu         690  47.260274
# 0    LotFrontage         259  17.739726
# 11    GarageType          81   5.547945
# 12   GarageYrBlt          81   5.547945
# 13  GarageFinish          81   5.547945
# 14    GarageQual          81   5.547945
# 15    GarageCond          81   5.547945
# 8   BsmtFinType2          38   2.602740
# 6   BsmtExposure          38   2.602740
# 7   BsmtFinType1          37   2.534247
# 5       BsmtCond          37   2.534247
# 4       BsmtQual          37   2.534247
# 3     MasVnrArea           8   0.547945
# 9     Electrical           1   0.068493

# %%
df1 = df.copy()

# %%
cols = ['PoolQC','MiscFeature','Alley','Fence']
for i in cols:
    print(i,df[i].unique())
# Out:
# PoolQC [nan 'Ex' 'Fa' 'Gd']
# MiscFeature [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# Alley [nan 'Grvl' 'Pave']
# Fence [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']

# %%
df.drop(['PoolQC','MiscFeature','Alley','Fence'],axis=1,inplace=True)

# %%
nv_df = fetch_null_val(df)
nv_df
# Out:
#          Feature  Null_Count      %Null
# 1     MasVnrType         872  59.726027
# 9    FireplaceQu         690  47.260274
# 0    LotFrontage         259  17.739726
# 10    GarageType          81   5.547945
# 11   GarageYrBlt          81   5.547945
# 12  GarageFinish          81   5.547945
# 13    GarageQual          81   5.547945
# 14    GarageCond          81   5.547945
# 5   BsmtExposure          38   2.602740
# 7   BsmtFinType2          38   2.602740
# 3       BsmtQual          37   2.534247
# 4       BsmtCond          37   2.534247
# 6   BsmtFinType1          37   2.534247
# 2     MasVnrArea           8   0.547945
# 8     Electrical           1   0.068493

# %%
nv_df['Feature'].values
# Out:
# array(['MasVnrType', 'FireplaceQu', 'LotFrontage', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond',
#        'BsmtFinType1', 'MasVnrArea', 'Electrical'], dtype=object)

# %% [markdown]
# ### Basement related Features¶

# %%
cols = ['BsmtExposure','BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']
for i in cols:
    print(i,df[i].unique())
# Out:
# BsmtExposure ['No' 'Gd' 'Mn' 'Av' nan]
# BsmtFinType2 ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# BsmtQual ['Gd' 'TA' 'Ex' nan 'Fa']
# BsmtCond ['TA' 'Gd' nan 'Fa' 'Po']
# BsmtFinType1 ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']

# %%
cols = ['BsmtExposure','BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1']
for i in cols:
    df[i] = df[i].fillna('No Basement')

# %% [markdown]
# #### Garage Related Faetures¶

# %%
cols = ['GarageType','GarageFinish', 'GarageQual', 'GarageCond']  #  'GarageYrBlt'
for i in cols:
    print(i,df[i].unique())
# Out:
# GarageType ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageFinish ['RFn' 'Unf' 'Fin' nan]
# GarageQual ['TA' 'Fa' 'Gd' nan 'Ex' 'Po']
# GarageCond ['TA' 'Fa' nan 'Gd' 'Po' 'Ex']

# %%
cols = ['GarageType','GarageFinish', 'GarageQual', 'GarageCond']
for i in cols:
    df[i] = df[i].fillna('No Garage')

# %%
cols = ['LotFrontage','MasVnrArea']
for i in cols:
    print(df[i].value_counts())
# Out:
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64
# MasVnrArea
# 0.0      861
# 180.0      8
# 72.0       8
# 108.0      8
# 120.0      7
#         ...
# 562.0      1
# 89.0       1
# 921.0      1
# 762.0      1
# 119.0      1
# Name: count, Length: 327, dtype: int64

# %%
cols = ['LotFrontage','MasVnrArea']
for i in cols:
    df[i] = df[i].fillna(df[i].median())

# %%
nv_df = fetch_null_val(df)
nv_df
# Out:
#        Feature  Null_Count      %Null
# 0   MasVnrType         872  59.726027
# 2  FireplaceQu         690  47.260274
# 3  GarageYrBlt          81   5.547945
# 1   Electrical           1   0.068493

# %%
df['MasVnrType'].value_counts(dropna=False)
# Out:
# MasVnrType
# NaN        872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
df['GarageYrBlt'].nunique()
# Out:
# 97

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode()[0])

# df['GarageYrBlt'].mode()[0] or df['GarageYrBlt'].mode().max()

# %%
df['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('No Fireplace')

# %%
nv_df = fetch_null_val(df)
nv_df
# Out:
#       Feature  Null_Count      %Null
# 0  MasVnrType         872  59.726027
# 1  Electrical           1   0.068493

# %%
df['MasVnrType'] = df['MasVnrType'].fillna('others')

# %%
df.shape
# Out:
# (1460, 77)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1459, 77)

# %%
nv_df = fetch_null_val(df)
nv_df
# Out:
# Empty DataFrame
# Columns: [Feature, Null_Count, %Null]
# Index: []

# %% [markdown]
# #### 2) Handle Duplicates :

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 77, dtype: object

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.shape
# Out:
# (1459, 76)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### 3) Seperate Numerical and Categorical Cols :

# %%
cat_cols = df.dtypes[df.dtypes=='object'].index
num_cols = df.dtypes[df.dtypes!='object'].index
print('Cat_Cols', cat_cols)
print('Num_Cols', num_cols)
# Out:
# Cat_Cols Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')
# Num_Cols Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
len(cat_cols)
# Out:
# 39

# %% [markdown]
# ### 4) EDA :

# %% [markdown]
# #### Univariate - CountPlot :

# %%
plt.figure(figsize=(12,100))
for i in range(len(cat_cols)): 
    plt.subplot(20,2,i+1)
    ax = sns.countplot(y=df[cat_cols[i]])
    ax.bar_label(ax.containers[0])
    plt.title(f'Countplot for {cat_cols[i]}')
plt.show()

# %%
cols_to_drop = ['Street', 'Utilities', 'LandSlope', 'Condition2', 'RoofMatl', 'Heating', 'Functional']

# %%
df.drop(cols_to_drop, axis=1, inplace=True)

# %%
df.shape
# Out:
# (1459, 69)

# %% [markdown]
# #### Bivariate - ScatterPlot :
# num-num

# %%
cols = num_cols[:-1]
print(cols)
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
print(len(cols))
# Out:
# 36

# %%
plt.figure(figsize=(12,90))
for i in range(len(cols)): 
    plt.subplot(18,2,i+1)
    sns.scatterplot(x=df[cols[i]],y=df['SalePrice'])
    plt.title(f'Scatterplot for {cols[i]} wrt SalePrice')
plt.show()

# %%
cols_to_drop_num = ['LowQualFinSF', '3SsnPorch', 'PoolArea', 'MiscVal']

# %%
df.drop(cols_to_drop_num, axis=1, inplace=True)

# %%
df.shape
# Out:
# (1459, 65)

# %%
cat_cols = df.dtypes[df.dtypes=='object'].index
num_cols = df.dtypes[df.dtypes!='object'].index
print('Cat_Cols', cat_cols)
print('Num_Cols', num_cols)
# Out:
# Cat_Cols Index(['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'Neighborhood',
#        'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
# Num_Cols Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'ScreenPorch', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### Correlation :

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
##### This command is used to install seaborn new version for correlation values :

# %%
# !pip install seaborn==0.13.2

# %%
corr = df[num_cols].corr()
plt.figure(figsize=(25,25))
sns.heatmap(corr,annot=True,cmap='RdBu')
plt.show()

# %% [markdown]
# ### Outliers Treatment :

# %%
len(num_cols)
# Out:
# 33

# %%
plt.figure(figsize=(12,85))
for i in range(len(num_cols)):
    plt.subplot(17,2,i+1)
    sns.boxplot(x=df[num_cols[i]])
    plt.title(f'Boxplot for {num_cols[i]}')
plt.show()

# %%
print(df.shape)
# Out:
# (1459, 65)

# %%
print(df[df['BsmtFinSF2']==0].shape)
print(df[df['BsmtHalfBath']==0].shape)
print(df[df['EnclosedPorch']==0].shape)
print(df[df['ScreenPorch']==0].shape)
# Out:
# (1292, 65)
# (1377, 65)
# (1251, 65)
# (1343, 65)

# %%
## (1251/1459)*100

# %%
num_cols_to_drop = ['BsmtFinSF2', 'BsmtHalfBath', 'EnclosedPorch', 'ScreenPorch']

df.drop(num_cols_to_drop, axis=1, inplace=True)

# %%
df.shape
# Out:
# (1459, 61)

# %%
num_cols = df.dtypes[df.dtypes!='object'].index
print(len(num_cols))
print(num_cols)
# Out:
# 29
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
a1 = df[num_cols].describe(percentiles=[0.01, 0.02, 0.03, 0.05, 0.95, 0.97, 0.98, 0.99]).T

a1 = a1.iloc[:,3:]
a1
# Out:
#                   min        1%        2%        3%       5%       50%  \
# MSSubClass       20.0     20.00     20.00     20.00     20.0      50.0
# LotFrontage      21.0     21.00     24.00     30.00     35.9      69.0
# LotArea        1300.0   1680.00   2123.88   2522.00   3307.4    9477.0
# OverallQual       1.0      3.00      4.00      4.00      4.0       6.0
# OverallCond       1.0      3.00      3.00      4.00      4.0       5.0
# YearBuilt      1872.0   1899.16   1908.32   1910.00   1916.0    1973.0
# YearRemodAdd   1950.0   1950.00   1950.00   1950.00   1950.0    1994.0
# MasVnrArea        0.0      0.00      0.00      0.00      0.0       0.0
# BsmtFinSF1        0.0      0.00      0.00      0.00      0.0     384.0
# BsmtUnfSF         0.0      0.00      0.00      0.00      0.0     479.0
# TotalBsmtSF       0.0      0.00      0.00    311.46    520.0     992.0
# 1stFlrSF        334.0    520.00    583.40    625.00    672.9    1088.0
# 2ndFlrSF          0.0      0.00      0.00      0.00      0.0       0.0
# GrLivArea       334.0    692.16    768.00    796.00    848.0    1464.0
# BsmtFullBath      0.0      0.00      0.00      0.00      0.0       0.0
# FullBath          0.0      1.00      1.00      1.00      1.0       2.0
# HalfBath          0.0      0.00      0.00      0.00      0.0       0.0
# BedroomAbvGr      0.0      1.00      1.00      1.00      2.0       3.0
# KitchenAbvGr      0.0      1.00      1.00      1.00      1.0       1.0
# TotRmsAbvGrd      2.0      3.00      4.00      4.00      4.0       6.0
# Fireplaces        0.0      0.00      0.00      0.00      0.0       1.0
# GarageYrBlt    1900.0   1917.16   1920.00   1924.00   1930.0    1984.0
# GarageCars        0.0      0.00      0.00      0.00      0.0       2.0
# GarageArea        0.0      0.00      0.00      0.00      0.0     480.0
# WoodDeckSF        0.0      0.00      0.00      0.00      0.0       0.0
# OpenPorchSF       0.0      0.00      0.00      0.00      0.0      25.0
# MoSold            1.0      1.00      1.00      1.00      2.0       6.0
# YrSold         2006.0   2006.00   2006.00   2006.00   2006.0    2008.0
# SalePrice     34900.0  61802.14  79000.00  82000.00  88000.0  163000.0
#
#                    95%        97%        98%        99%       max
# MSSubClass       160.0     160.00     188.40     190.00     190.0
# LotFrontage      104.0     114.00     120.84     137.42     313.0
# LotArea        17402.3   21576.60   25255.44   37593.68  215245.0
# OverallQual        8.0       9.00       9.00      10.00      10.0
# OverallCond        8.0       8.00       8.00       9.00       9.0
# YearBuilt       2007.0    2007.00    2008.00    2009.00    2010.0
# YearRemodAdd    2007.0    2008.00    2008.00    2009.00    2010.0
# MasVnrArea       456.0     573.78     650.84     791.36    1600.0
# BsmtFinSF1      1274.0    1376.38    1442.68    1572.42    5644.0
# BsmtUnfSF       1468.0    1589.56    1678.40    1797.10    2336.0
# TotalBsmtSF     1753.0    1905.52    2001.68    2155.10    6110.0
# 1stFlrSF        1831.5    1981.82    2072.36    2219.52    4692.0
# 2ndFlrSF        1141.1    1245.86    1318.72    1419.04    2065.0
# GrLivArea       2466.2    2633.26    2782.56    3123.76    5642.0
# BsmtFullBath       1.0       1.00       1.00       2.00       3.0
# FullBath           2.0       2.00       3.00       3.00       3.0
# HalfBath           1.0       1.00       1.00       1.00       2.0
# BedroomAbvGr       4.0       4.00       4.00       5.00       8.0
# KitchenAbvGr       1.0       2.00       2.00       2.00       3.0
# TotRmsAbvGrd      10.0      10.00      10.84      11.00      14.0
# Fireplaces         2.0       2.00       2.00       2.00       3.0
# GarageYrBlt     2007.0    2008.00    2008.00    2009.00    2010.0
# GarageCars         3.0       3.00       3.00       3.00       4.0
# GarageArea       850.2     884.00     907.52    1002.98    1418.0
# WoodDeckSF       335.0     385.56     430.20     505.52     857.0
# OpenPorchSF      175.1     213.26     240.84     285.84     547.0
# MoSold            11.0      12.00      12.00      12.00      12.0
# YrSold          2010.0    2010.00    2010.00    2010.00    2010.0
# SalePrice     326200.0  374260.00  394938.72  442629.62  755000.0

# %%
left_sk_cols = ['LotArea', 'GrLivArea', 'SalePrice', '1stFlrSF']

right_sk_cols = ['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea',
                 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'SalePrice', 'BedroomAbvGr']

# %%
df1 = df.copy()

# %%
for i in left_sk_cols:
    lower = df[i].quantile(0.01)
    df[i] = np.where(df[i]<lower,lower,df[i])

# %%
for i in right_sk_cols:                      
    upper = df[i].quantile(0.99)
    df[i] = np.where(df[i]>upper,upper,df[i])

# %%
a1 = df[num_cols].describe(percentiles=[0.01, 0.02, 0.03, 0.05, 0.95, 0.97, 0.98, 0.99]).T

a1 = a1.iloc[:,3:]
a1
# Out:
#                    min          1%        2%        3%       5%       50%  \
# MSSubClass       20.00     20.0000     20.00     20.00     20.0      50.0
# LotFrontage      21.00     21.0000     24.00     30.00     35.9      69.0
# LotArea        1680.00   1680.0000   2123.88   2522.00   3307.4    9477.0
# OverallQual       1.00      3.0000      4.00      4.00      4.0       6.0
# OverallCond       1.00      3.0000      3.00      4.00      4.0       5.0
# YearBuilt      1872.00   1899.1600   1908.32   1910.00   1916.0    1973.0
# YearRemodAdd   1950.00   1950.0000   1950.00   1950.00   1950.0    1994.0
# MasVnrArea        0.00      0.0000      0.00      0.00      0.0       0.0
# BsmtFinSF1        0.00      0.0000      0.00      0.00      0.0     384.0
# BsmtUnfSF         0.00      0.0000      0.00      0.00      0.0     479.0
# TotalBsmtSF       0.00      0.0000      0.00    311.46    520.0     992.0
# 1stFlrSF        520.00    520.0000    583.40    625.00    672.9    1088.0
# 2ndFlrSF          0.00      0.0000      0.00      0.00      0.0       0.0
# GrLivArea       692.16    692.6472    768.00    796.00    848.0    1464.0
# BsmtFullBath      0.00      0.0000      0.00      0.00      0.0       0.0
# FullBath          0.00      1.0000      1.00      1.00      1.0       2.0
# HalfBath          0.00      0.0000      0.00      0.00      0.0       0.0
# BedroomAbvGr      0.00      1.0000      1.00      1.00      2.0       3.0
# KitchenAbvGr      0.00      1.0000      1.00      1.00      1.0       1.0
# TotRmsAbvGrd      2.00      3.0000      4.00      4.00      4.0       6.0
# Fireplaces        0.00      0.0000      0.00      0.00      0.0       1.0
# GarageYrBlt    1900.00   1917.1600   1920.00   1924.00   1930.0    1984.0
# GarageCars        0.00      0.0000      0.00      0.00      0.0       2.0
# GarageArea        0.00      0.0000      0.00      0.00      0.0     480.0
# WoodDeckSF        0.00      0.0000      0.00      0.00      0.0       0.0
# OpenPorchSF       0.00      0.0000      0.00      0.00      0.0      25.0
# MoSold            1.00      1.0000      1.00      1.00      2.0       6.0
# YrSold         2006.00   2006.0000   2006.00   2006.00   2006.0    2008.0
# SalePrice     61802.14  62139.0388  79000.00  82000.00  88000.0  163000.0
#
#                    95%        97%        98%          99%        max
# MSSubClass       160.0     160.00     188.40     190.0000     190.00
# LotFrontage      104.0     114.00     120.84     137.1764     137.42
# LotArea        17402.3   21576.60   25255.44   36959.3456   37593.68
# OverallQual        8.0       9.00       9.00      10.0000      10.00
# OverallCond        8.0       8.00       8.00       9.0000       9.00
# YearBuilt       2007.0    2007.00    2008.00    2009.0000    2010.00
# YearRemodAdd    2007.0    2008.00    2008.00    2009.0000    2010.00
# MasVnrArea       456.0     573.78     650.84     789.4112     791.36
# BsmtFinSF1      1274.0    1376.38    1442.68    1572.1764    1572.42
# BsmtUnfSF       1468.0    1589.56    1678.40    1795.8820    1797.10
# TotalBsmtSF     1753.0    1905.52    2001.68    2153.8820    2155.10
# 1stFlrSF        1831.5    1981.82    2072.36    2218.0584    2219.52
# 2ndFlrSF        1141.1    1245.86    1318.72    1416.1168    1419.04
# GrLivArea       2466.2    2633.26    2782.56    3116.9392    3123.76
# BsmtFullBath       1.0       1.00       1.00       2.0000       3.00
# FullBath           2.0       2.00       3.00       3.0000       3.00
# HalfBath           1.0       1.00       1.00       1.0000       2.00
# BedroomAbvGr       4.0       4.00       4.00       5.0000       5.00
# KitchenAbvGr       1.0       2.00       2.00       2.0000       3.00
# TotRmsAbvGrd      10.0      10.00      10.84      11.0000      14.00
# Fireplaces         2.0       2.00       2.00       2.0000       3.00
# GarageYrBlt     2007.0    2008.00    2008.00    2009.0000    2010.00
# GarageCars         3.0       3.00       3.00       3.0000       4.00
# GarageArea       850.2     884.00     907.52     998.3516    1002.98
# WoodDeckSF       335.0     385.56     430.20     504.0584     505.52
# OpenPorchSF      175.1     213.26     240.84     285.3528     285.84
# MoSold            11.0      12.00      12.00      12.0000      12.00
# YrSold          2010.0    2010.00    2010.00    2010.0000    2010.00
# SalePrice     326200.0  374260.00  394938.72  441104.4404  442629.62

# %% [markdown]
# #### Dummy Variable Features - Encoding Categorical Features  (ENCODING STEP) :

# %%
df['Neighborhood'].unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
df['ExterCond'].value_counts()

## Encoding Order : {Po : 0 , FA : 1 , TA : 2 , Gd : 3 , Ex : 4}  
## which is not the correct order as it was labelled wrong. Therefore, here we use : LabelEncoder {Target Variable} , OneHotEncoder,
##                                     OridinalEncoder [[here, we use as data is Ordinal]]
# Out:
# ExterCond
# TA    1281
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: count, dtype: int64

# %%
for i in cat_cols:
    print(i,df[i].nunique())
# Out:
# MSZoning 5
# LotShape 4
# LandContour 4
# LotConfig 5
# Neighborhood 25
# Condition1 9
# BldgType 5
# HouseStyle 8
# RoofStyle 6
# Exterior1st 15
# Exterior2nd 16
# MasVnrType 4
# ExterQual 4
# ExterCond 5
# Foundation 6
# BsmtQual 5
# BsmtCond 5
# BsmtExposure 5
# BsmtFinType1 7
# BsmtFinType2 7
# HeatingQC 5
# CentralAir 2
# Electrical 5
# KitchenQual 4
# FireplaceQu 6
# GarageType 7
# GarageFinish 4
# GarageQual 6
# GarageCond 6
# PavedDrive 3
# SaleType 9
# SaleCondition 6

# %%
cat_cols
# Out:
# Index(['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'Neighborhood',
#        'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
### REMOVE / DROP the Columns "NEIGHBORHOOD" and "EXTERIOR2nd" and "EXTERIOR1st => Not to ENCODE these columns as they contain large no of categories..

cols_to_encode = ['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 
       'Condition1', 'BldgType', 'HouseStyle', 'RoofStyle', 'MasVnrType','ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'FireplaceQu',
       'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive',
       'SaleType', 'SaleCondition']

# %%
df_dummy = pd.get_dummies(data=df, columns=cols_to_encode, dtype=int, drop_first=True)  

## data is df , columns = for which u have to create dummy var..
## drop_first = True is used so that if we remove one column, then aslo we will get to know the interpretation of dummy columns..

print(df_dummy.shape)
print(df_dummy.columns)
# Out:
# (1459, 160)
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'Neighborhood', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'Exterior1st',
#        'Exterior2nd',
#        ...
#        'SaleType_ConLI', 'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth',
#        'SaleType_WD', 'SaleCondition_AdjLand', 'SaleCondition_Alloca',
#        'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=160)

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder

# %%
df_dummy.dtypes.value_counts()
# Out:
# int32      128
# float64     15
# int64       14
# object       3
# Name: count, dtype: int64

# %% [markdown]
# #### Select x and y :

# %%
plt.subplot(1,2,1)
sns.histplot(df['SalePrice'],kde=True)
plt.subplot(1,2,2)
sns.histplot(np.log(df['SalePrice']),kde=True)
plt.show()

# %%
x = df_dummy.drop(['Neighborhood', 'Exterior1st', 'Exterior2nd', 'SalePrice'],axis=1)

y = df_dummy['SalePrice']

print(x.shape)
print(y.shape)
# Out:
# (1459, 156)
# (1459,)

# %% [markdown]
# ### Split Data into Train and Test :

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=37)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1021, 156) (438, 156)
# (1021,) (438,)

# %%
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression

# %%
def eval_model(y_pred):
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    print('MAE', mae, 'MSE', mse, 'RMSE', rmse, 'R2', r2)

# %% [markdown]
# ### LinReg before PCA :

# %%
lr1 = LinearRegression()
lr1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
ypred_lr1 = lr1.predict(x_test)
eval_model(ypred_lr1)
# Out:
# MAE 18845.292505325808 MSE 770087120.3980011 RMSE 27750.443607229077 R2 0.8494416166583267

# %%
print('Train_Score', lr1.score(x_train, y_train))
print('Test_Score', lr1.score(x_test, y_test))
# Out:
# Train_Score 0.915639416514024
# Test_Score 0.8494416166583267

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)
print(x_train_sc.shape)
print(x_test_sc.shape)
# Out:
# (1021, 156)
# (438, 156)

# %%
pca  = PCA()
pcomps_train =  pca.fit_transform(x_train_sc)
pcomps_test  =  pca.transform(x_test_sc)
print(pcomps_train.shape)
print(pcomps_test.shape)
# Out:
# (1021, 156)
# (438, 156)

# %% [markdown]
# ### Compute Eigen_value and Eigen_vector :

# %%
eig_val = pca.explained_variance_
eig_vec = pca.components_

# %%
eig_data_df = pd.DataFrame({'EV':eig_val})
eig_data_df['Var_EV'] = (eig_data_df['EV']/eig_data_df['EV'].sum())*100
eig_data_df['CumSum_Var_EV'] = eig_data_df['Var_EV'].cumsum()
eig_data_df.head(10)
# Out:
#           EV    Var_EV  CumSum_Var_EV
# 0  15.372494  9.844512       9.844512
# 1   6.998554  4.481858      14.326370
# 2   6.394027  4.094721      18.421091
# 3   5.552331  3.555701      21.976792
# 4   5.028326  3.220129      25.196920
# 5   4.190826  2.683796      27.880716
# 6   3.319687  2.125920      30.006637
# 7   3.065188  1.962940      31.969576
# 8   2.844885  1.821858      33.791434
# 9   2.620631  1.678246      35.469681

# %% [markdown]
# ### Scree Plot

# %%
plt.plot(list(range(156)),eig_data_df['CumSum_Var_EV'])
plt.title('Scree Plot')
plt.xlabel('PCs')
plt.ylabel('Var_Eig_Val')
plt.grid()
plt.show()

# %%
eig_data_df[eig_data_df['CumSum_Var_EV']>=79]
# Out:
#                EV        Var_EV  CumSum_Var_EV
# 59   9.157272e-01  5.864297e-01      79.382194
# 60   8.955003e-01  5.734764e-01      79.955671
# 61   8.820717e-01  5.648768e-01      80.520547
# 62   8.647383e-01  5.537765e-01      81.074324
# 63   8.532390e-01  5.464124e-01      81.620736
# ..            ...           ...            ...
# 151  3.031690e-30  1.941488e-30     100.000000
# 152  6.906397e-32  4.422842e-32     100.000000
# 153  6.906397e-32  4.422842e-32     100.000000
# 154  6.906397e-32  4.422842e-32     100.000000
# 155  6.906397e-32  4.422842e-32     100.000000
#
# [97 rows x 3 columns]

# %% [markdown]
# #### Inference
# 1) Containing 53 PCs, ensures that 75% of variance is retained<br>
# 2) Containing 62 PCs, ensures that 80% of variance is retained.

# %%
pc_list = ['PC'+str(i) for i in range(156)]

# %%
pcomps_train_df = pd.DataFrame(pcomps_train,columns=pc_list)
pcomps_test_df = pd.DataFrame(pcomps_test,columns=pc_list)
print(pcomps_train_df.shape)
print(pcomps_test_df.shape)
# Out:
# (1021, 156)
# (438, 156)

# %%
pcomps_train_df = pcomps_train_df.iloc[:,:62]
pcomps_test_df = pcomps_test_df.iloc[:,:62]
print(pcomps_train_df.shape)
print(pcomps_test_df.shape)
# Out:
# (1021, 62)
# (438, 62)

# %% [markdown]
# ### Linear Regression after PCA :

# %%
lr2 = LinearRegression()
lr2.fit(pcomps_train_df,y_train)
# Out:
# LinearRegression()

# %%
ypred_lr2 = lr2.predict(pcomps_test_df)
eval_model(ypred_lr2)
# Out:
# MAE 20850.41104947625 MSE 825486210.9735621 RMSE 28731.275832680352 R2 0.8386106375460614

# %%
print('Train_score',lr2.score(pcomps_train_df,y_train))
print('Test_score',lr2.score(pcomps_test_df,y_test))
# Out:
# Train_score 0.8478315671430959
# Test_score 0.8386106375460614

# %%
### PREVIOUS LINEAR REGRESSION SCORES BEFORE PCA :

# %%
print('Train_score',lr1.score(x_train,y_train))
print('Test_score',lr1.score(x_test,y_test))
# Out:
# Train_score 0.915639416514024
# Test_score 0.8494416166583267
